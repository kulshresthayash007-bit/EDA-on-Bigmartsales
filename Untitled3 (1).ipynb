# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("BigMart_sales.csv") #Read the data

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# ### Column Description
# - Item identifier : A key column to identify each column
# - Item-Weight : The weight of the item content
# - Item_Fat_Content : The % of the total display area in a store allocated to the particular product
# - Item_MRP :
# - MRP of the items :
# - Outlet_Identifier :
# - Outlet_Establishment_Year :
# - Outlet_Size :
# - Outlet_Location_Type :
# - Outlet_Type :
# - Item_Outlet_Sales : Total sales of the items in each outlet (The target in study)

# %% [markdown]
# #### Problem Statement:
# - Analyse the data and understand the factos impacting the sales in each outlet
# - Identify the anomalies and trends in the data using charts and visuals
# - Handle missing and outliers with appropriatetechniques and clean the data

# %% [markdown]
# #### Load the data into your analysis environment, ensuring it is imported correctly and without errors or truncations.
# - Examine the dimensions of the data (number of rows and columns) to get a sense of its size and complexity.
# - Check for missing values and their distribution across variables, as missing data can significantly affect the quality and reliability of your analysis.
# - Identify the data types and formats for each variable, as this information is essential for subsequent data manipulation and analysis steps.
# - Look for any obvious errors or inconsistencies in the data, such as invalid values, mismatched units, or outliers, which could indicate data quality issues.

# %%
df.isnull().sum()/len(df)
# Out:
# Item_Identifier              0.000000
# Item_Weight                  0.171653
# Item_Fat_Content             0.000000
# Item_Visibility              0.000000
# Item_Type                    0.000000
# Item_MRP                     0.000000
# Outlet_Identifier            0.000000
# Outlet_Establishment_Year    0.000000
# Outlet_Size                  0.282764
# Outlet_Location_Type         0.000000
# Outlet_Type                  0.000000
# Item_Outlet_Sales            0.000000
# dtype: float64

# %% [markdown]
# Missing values are found in item weight column 1463 as a count and 17%) and outlet size (2410, approx 25%) Missing data can significantly affect the quality and reliability of your analysis and therefore needs to be handled during the process.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# 1.) The categorical columns are: Irtems_Fat_Content, Item_Type, Outlet_Location_Type, Outlet_Type
# 2.) Numerical_Columns : Item_weight, Item_Visibility, item_MRP, Outlet_Establishment_Year, Item_Count_Sales

# %%
categorical_columns = df.select_dtypes(include = "object").columns
numerical_columns =  df.select_dtypes(include = ["int64", "Float64"]).columns

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Item_Fat_Content"].unique()
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'LF', 'reg'], dtype=object)

# %%
### For every

# %%
for cat in categorical_columns:
    print("Unique values and their counts in {cat}")
    print(df[cat].value_counts())
    print("*******************************")
# Out:
# Unique values and their counts in {cat}
# Item_Identifier
# FDW13    10
# FDG33    10
# FDX31     9
# FDT07     9
# NCY18     9
#          ..
# FDO33     1
# FDK57     1
# FDT35     1
# FDN52     1
# FDE52     1
# Name: count, Length: 1559, dtype: int64
# *******************************
# Unique values and their counts in {cat}
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64
# *******************************
# Unique values and their counts in {cat}
# Item_Type
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# ...

# %%
df.rename(columns={'LF': 'Low Fat','Reg': 'regular' })
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
#### Combine all supermarket types to Supermarket Label
df['Outlet_Type'] = df['Outlet_Type'].replace({"Supermarket Type1" :"Supermarket",
                                               "Supermarket Type2" :"Supermarket",
                                               "Supermarket Type3" :"Supermarket"})

# %%
df['Outlet_Type'].value_counts()
# Out:
# Outlet_Type
# Supermarket      7440
# Grocery Store    1083
# Name: count, dtype: int64

# %%
df[df['Item_Weight'].isnull()]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7              FDP10          NaN          Low Fat         0.127470
# 18             DRI11          NaN          Low Fat         0.034238
# 21             FDW12          NaN          Regular         0.035400
# 23             FDC37          NaN          Low Fat         0.057557
# 29             FDC14          NaN          Regular         0.072222
# ...              ...          ...              ...              ...
# 8485           DRK37          NaN          Low Fat         0.043792
# 8487           DRG13          NaN          Low Fat         0.037006
# 8488           NCN14          NaN          Low Fat         0.091473
# 8490           FDU44          NaN          Regular         0.102296
# 8504           NCN18          NaN          Low Fat         0.124111
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7               Snack Foods  107.7622            OUT027
# ...

# %%
df['Item_Weight'].mean(), df['Item_Weight'].median()
# Out:
# (np.float64(12.857645184135976), 12.6)

# %%
df["Outlet_Size"].mode()
# Out:
# 0    Medium
# Name: Outlet_Size, dtype: object

# %%
df.fillna({'Item_Weight' : df['Item_Weight'].median(), "Outlet_Size" : df["Outlet_Size"].mode()[0]}, inplace = True)

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %% [markdown]
# ##### Step 4. Perform Univanate Analysis with distribution plots/countplots Univariate analysis is the simplest form of data analysis. It involves analysing data with only one variable to understand its clistribution, central tendency, and dispersion

# %%
### Distribution plots for numerical columns
for num in numerical_columns:
    if num !="Outlet_Establishment_Year":
        sns.displot(data = df, x = num, bins = 15, height = 3, aspect = 2, kde = True)
        plt.axvline(df[num].mean(), label = "mean")
        plt.axvline
        plt.title(f'Distribution plot of {num}')
        plt.show()

# %% [markdown]
# - Item outlet sales and item visibility is positively skewed
# - Not a clear pattern is visible in item_weight although the data seems symetrical
# - Majority of the weights around 12 units
# - MRP values seems to follow approx. uniform distribution

# %%
## Create countplot for all categorical columns including establishment year

# %%
for cat in categorical_columns:
    if cat != "Item_Identifier":
        plt.figure(figsize = (5,5))    
        sns.countplot(data = df, x = cat, hue = cat)
        plt.title(f"Count plots of {cat}")
        plt.xticks( rotation = 90)
        plt.show()
